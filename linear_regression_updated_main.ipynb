# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika8423/pythonbasics/blob/main/linear_regression_updated_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
wcat=pd.read_csv('wc.at.csv')
wcat
pd.set_option("display.min.rows",None)

# %%
wcat.shape
# Out:
# (109, 2)

# %%
wcat
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# 5     71.85   21.68
# 6     80.90   29.08
# 7     83.40   32.98
# 8     63.50   11.44
# 9     73.20   32.22
# 10    71.90   28.32
# 11    75.00   43.86
# 12    73.10   38.21
# 13    79.00   42.48
# 14    77.00   30.96
# 15    68.85   55.78
# 16    75.95   43.78
# 17    74.15   33.41
# 18    73.80   43.35
# 19    75.90   29.31
# 20    76.85   36.60
# 21    80.90   40.25
# 22    79.90   35.43
# 23    89.20   60.09
# 24    82.00   45.84
# 25    92.00   70.40
# 26    86.60   83.45
# 27    80.50   84.30
# 28    86.00   78.89
# 29    82.50   64.75
# ..      ...     ...
# 79   109.00  192.00
# 80   103.50  132.00
# 81   110.00  126.00
# 82   110.00  153.00
# 83   112.00  158.00
# 84   108.50  183.00
# 85   104.00  184.00
# 86   111.00  121.00
# 87   108.50  159.00
# 88   121.00  245.00
# 89   109.00  137.00
# 90    97.50  165.00
# 91   105.50  152.00
# 92    98.00  181.00
# 93    94.50   80.95
# 94    97.00  137.00
# 95   105.00  125.00
# 96   106.00  241.00
# 97    99.00  134.00
# 98    91.00  150.00
# 99   102.50  198.00
# 100  106.00  151.00
# 101  109.10  229.00
# 102  115.00  253.00
# 103  101.00  188.00
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
wcat.describe()
# Out:
#             Waist          AT
# count  109.000000  109.000000
# mean    91.901835  101.894037
# std     13.559116   57.294763
# min     63.500000   11.440000
# 25%     80.000000   50.880000
# 50%     90.800000   96.540000
# 75%    104.000000  137.000000
# max    121.000000  253.000000

# %%
wcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
wcat.isnull().sum()
# Out:
# Waist    0
# AT       0
# dtype: int64

# %%
wcat.columns
# Out:
# Index(['Waist', 'AT'], dtype='object')

# %%
plt.boxplot(wcat.Waist)
plt.show()

# %%
plt.plot(wcat.Waist,wcat.AT,'rs')
plt.xlabel('Waist')
plt.ylabel("AT")
plt.title("scatterplot")
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
wcat.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
import statsmodels.formula.api as smf
model=smf.ols('AT~Waist',data=wcat).fit()
model.params
# Out:
# Intercept   -215.981488
# Waist          3.458859
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AT   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):           1.62e-27
# Time:                        10:48:37   Log-Likelihood:                -534.99
# No. Observations:                 109   AIC:                             1074.
# Df Residuals:                     107   BIC:                             1079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -215.9815     21.796     -9.909      0.000    -259.190    -172.773
# Waist          3.4589      0.235     14.740      0.000       2.994       3.924
# ==============================================================================
# Omnibus:                        3.960   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                4.596
# Skew:                           0.104   Prob(JB):                        0.100
# Kurtosis:                       3.984   Cond. No.                         639.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pred=model.predict(wcat.Waist)
model.resid
# Out:
# 0     -16.848252
# 1      -9.241704
# 2     -24.353210
# 3     -31.589758
# 4     -12.382366
# 5     -10.857559
# 6     -34.760237
# 7     -39.507385
# 8       7.783917
# 9      -4.987020
# 10     -4.390502
# 11      0.427034
# 12      1.348866
# 13    -14.788404
# 14    -19.390685
# 15     33.619019
# 16     -2.938883
# 17     -7.082936
# 18      4.067665
# 19    -17.235940
# 20    -13.231856
# 21    -23.590237
# 22    -24.951377
# 23    -32.458770
# 24    -21.804982
# 25    -31.833576
# 26     -0.105735
# 27     21.843307
# 28     -2.590420
# 29     -4.624412
#          ...
# 79     30.965814
# 80    -10.010459
# 81    -38.493045
# 82    -11.493045
# 83    -13.410764
# 84     23.695244
# 85     40.260111
# 86    -46.951905
# 87     -0.304756
# 88     42.459502
# 89    -24.034186
# 90     43.742697
# 91      3.071822
# 92     58.013268
# 93    -29.930725
# 94     17.472127
# 95    -22.198748
# 96     90.342392
# 97      7.554408
# 98     51.225283
# 99     59.448400
# 100     0.342392
# 101    67.619928
# 102    71.212658
# 103    54.636689
# 104    -6.250337
# 105   -44.530093
# 106    -3.130398
# 107    50.770560
# 108    48.695244
# Length: 109, dtype: float64

# %%
rmse_lin=np.sqrt(np.mean((np.array(wcat['AT'])-np.array(pred))**2))
rmse_lin
# Out:
# 32.760177495755144

# %%
plt.scatter(x=wcat['Waist'],y=wcat['AT'],color='red')
plt.plot(wcat['Waist'],pred,color='black')
plt.xlabel('Waist')
plt.ylabel('Tissue')
# Out:
# Text(0, 0.5, 'Tissue')

# %%
model2=smf.ols('AT~np.log(Waist)',data=wcat).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AT   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     222.6
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):           6.80e-28
# Time:                        10:52:47   Log-Likelihood:                -534.11
# No. Observations:                 109   AIC:                             1072.
# Df Residuals:                     107   BIC:                             1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1328.3420     95.923    -13.848      0.000   -1518.498   -1138.186
# np.log(Waist)   317.1356     21.258     14.918      0.000     274.994     359.277
# ==============================================================================
# Omnibus:                        3.317   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.190   Jarque-Bera (JB):                2.908
# Skew:                           0.235   Prob(JB):                        0.234
# Kurtosis:                       3.647   Cond. No.                         145.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pred2=model2.predict(pd.DataFrame(wcat['Waist']))
pred2
# Out:
# 0       39.828156
# 1       30.572779
# 2       68.410960
# 3       76.638769
# 4       39.403610
# 5       27.279545
# 6       64.902356
# 7       74.554213
# 8      -11.899606
# 9       33.182963
# 10      27.500161
# 11      40.887040
# 12      32.749422
# 13      57.365321
# 14      49.233194
# 15      13.753591
# 16      44.878862
# 17      37.272314
# 18      35.771839
# 19      44.670014
# 20      48.614795
# 21      64.902356
# 22      60.957833
# 23      95.876103
# 24      69.185406
# 25     105.677983
# 26      86.494845
# 27      63.330429
# 28      84.289954
# 29      71.113288
#           ...
# 79     159.451269
# 80     143.031172
# 81     162.347504
# 82     162.347504
# 83     168.061813
# 84     157.993171
# 85     144.559539
# 86     165.217529
# 87     157.993171
# 88     192.573752
# 89     159.451269
# 90     124.092079
# 91     149.100938
# 92     125.714259
# 93     114.180786
# 94     122.461558
# 95     147.594352
# 96     150.600399
# 97     128.933937
# 98     102.211986
# 99     139.952162
# 100    150.600399
# 101    159.742085
# 102    176.444739
# 103    135.276860
# 104    132.438233
# 105    110.127880
# 106    137.778929
# 107    156.234559
# 108    157.993171
# Length: 109, dtype: float64

# %%
pred2
rmse_log=np.sqrt(np.mean((np.array(wcat['AT'])-np.array(pred2))**2))
rmse_log
# Out:
# 32.49688490932126

# %%
pred.corr(wcat.AT)
# Out:
# 0.8185578128958535

# %%
plt.scatter(x=wcat['Waist'],y=wcat['AT'],color='green')
plt.plot(wcat['Waist'],pred2,color='blue')
plt.xlabel('Waist')
plt.ylabel('Tissue')
# Out:
# Text(0, 0.5, 'Tissue')

# %%
model3=smf.ols('np.log(AT)~Waist',data=wcat).fit()
model3.params
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             np.log(AT)   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     258.3
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):           2.68e-30
# Time:                        10:58:52   Log-Likelihood:                -40.123
# No. Observations:                 109   AIC:                             84.25
# Df Residuals:                     107   BIC:                             89.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7410      0.233      3.185      0.002       0.280       1.202
# Waist          0.0403      0.003     16.073      0.000       0.035       0.045
# ==============================================================================
# Omnibus:                        2.604   Durbin-Watson:                   1.201
# Prob(Omnibus):                  0.272   Jarque-Bera (JB):                2.117
# Skew:                          -0.329   Prob(JB):                        0.347
# Kurtosis:                       3.182   Cond. No.                         639.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pred_log=model3.predict(pd.DataFrame(wcat['Waist']))
pred_log
# Out:
# 0      3.749889
# 1      3.663346
# 2      4.033669
# 3      4.120211
# 4      3.745864
# 5      3.633157
# 6      3.997441
# 7      4.098072
# 8      3.297049
# 9      3.687498
# 10     3.635170
# 11     3.759952
# 12     3.683472
# 13     3.920962
# 14     3.840457
# 15     3.512400
# 16     3.798192
# 17     3.725738
# 18     3.711649
# 19     3.796179
# 20     3.834419
# 21     3.997441
# 22     3.957189
# 23     4.331536
# 24     4.041719
# 25     4.444243
# 26     4.226880
# 27     3.981340
# 28     4.202729
# 29     4.061845
#          ...
# 79     5.128534
# 80     4.907146
# 81     5.168787
# 82     5.168787
# 83     5.249292
# 84     5.108408
# 85     4.927272
# 86     5.209039
# 87     5.108408
# 88     5.611563
# 89     5.128534
# 90     4.665631
# 91     4.987651
# 92     4.685758
# 93     4.544874
# 94     4.645505
# 95     4.967525
# 96     5.007777
# 97     4.726010
# 98     4.403991
# 99     4.866894
# 100    5.007777
# 101    5.132560
# 102    5.370049
# 103    4.806515
# 104    4.770288
# 105    4.496571
# 106    4.838717
# 107    5.084257
# 108    5.108408
# Length: 109, dtype: float64

# %%
pred3=np.exp(pred_log)
pred3
# Out:
# 0       42.516361
# 1       38.991601
# 2       56.467684
# 3       61.572246
# 4       42.345566
# 5       37.832062
# 6       54.458630
# 7       60.224086
# 8       27.032754
# 9       39.944768
# 10      37.908280
# 11      42.946367
# 12      39.784304
# 13      50.448940
# 14      46.546737
# 15      33.528629
# 16      44.620431
# 17      41.501829
# 18      40.921236
# 19      44.530718
# 20      46.266541
# 21      54.458630
# 22      52.310071
# 23      76.061058
# 24      56.924111
# 25      85.135421
# 26      68.503177
# 27      53.588815
# 28      66.868544
# 29      58.081384
#           ...
# 79     168.769572
# 80     135.252851
# 81     175.701533
# 82     175.701533
# 83     190.431312
# 84     165.406833
# 85     138.002556
# 86     182.918215
# 87     165.406833
# 88     273.571587
# 89     168.769572
# 90     106.232649
# 91     146.591651
# 92     108.392370
# 93      94.148585
# 94     104.115960
# 95     143.670808
# 96     149.571875
# 97     112.844427
# 98      81.776569
# 99     129.916714
# 100    149.571875
# 101    169.450279
# 102    214.873357
# 103    122.304636
# 104    117.953181
# 105     89.709020
# 106    126.307181
# 107    161.459872
# 108    165.406833
# Length: 109, dtype: float64

# %%
rmse_exp=np.sqrt(np.mean((np.array(wcat['AT'])-np.array(pred3))**2))
rmse_exp
# Out:
# 38.52900175807143

# %%
pred3.corr(wcat.AT)
# Out:
# 0.7633804583650525

# %%
plt.scatter(x=wcat['Waist'],y=wcat['AT'],color='green')
plt.plot(wcat['Waist'],pred3,color='blue')
plt.xlabel('Waist')
plt.ylabel('Tissue')
# Out:
# Text(0, 0.5, 'Tissue')

# %%
wcat['Waist_sq']=wcat.Waist*wcat.Waist
wcat
# Out:
#       Waist      AT    Waist_sq
# 0     74.75   25.72   5587.5625
# 1     72.60   25.89   5270.7600
# 2     81.80   42.60   6691.2400
# 3     83.95   42.80   7047.6025
# 4     74.65   29.84   5572.6225
# 5     71.85   21.68   5162.4225
# 6     80.90   29.08   6544.8100
# 7     83.40   32.98   6955.5600
# 8     63.50   11.44   4032.2500
# 9     73.20   32.22   5358.2400
# 10    71.90   28.32   5169.6100
# 11    75.00   43.86   5625.0000
# 12    73.10   38.21   5343.6100
# 13    79.00   42.48   6241.0000
# 14    77.00   30.96   5929.0000
# 15    68.85   55.78   4740.3225
# 16    75.95   43.78   5768.4025
# 17    74.15   33.41   5498.2225
# 18    73.80   43.35   5446.4400
# 19    75.90   29.31   5760.8100
# 20    76.85   36.60   5905.9225
# 21    80.90   40.25   6544.8100
# 22    79.90   35.43   6384.0100
# 23    89.20   60.09   7956.6400
# 24    82.00   45.84   6724.0000
# 25    92.00   70.40   8464.0000
# 26    86.60   83.45   7499.5600
# 27    80.50   84.30   6480.2500
# 28    86.00   78.89   7396.0000
# 29    82.50   64.75   6806.2500
# ..      ...     ...         ...
# 79   109.00  192.00  11881.0000
# 80   103.50  132.00  10712.2500
# 81   110.00  126.00  12100.0000
# 82   110.00  153.00  12100.0000
# 83   112.00  158.00  12544.0000
# 84   108.50  183.00  11772.2500
# 85   104.00  184.00  10816.0000
# 86   111.00  121.00  12321.0000
# 87   108.50  159.00  11772.2500
# 88   121.00  245.00  14641.0000
# 89   109.00  137.00  11881.0000
# 90    97.50  165.00   9506.2500
# 91   105.50  152.00  11130.2500
# 92    98.00  181.00   9604.0000
# 93    94.50   80.95   8930.2500
# 94    97.00  137.00   9409.0000
# 95   105.00  125.00  11025.0000
# 96   106.00  241.00  11236.0000
# 97    99.00  134.00   9801.0000
# 98    91.00  150.00   8281.0000
# 99   102.50  198.00  10506.2500
# 100  106.00  151.00  11236.0000
# 101  109.10  229.00  11902.8100
# 102  115.00  253.00  13225.0000
# 103  101.00  188.00  10201.0000
# 104  100.10  124.00  10020.0100
# 105   93.30   62.20   8704.8900
# 106  101.80  133.00  10363.2400
# 107  107.90  208.00  11642.4100
# 108  108.50  208.00  11772.2500
#
# [109 rows x 3 columns]

# %%
model_quad=smf.ols('np.log(AT)~Waist+Waist_sq',data=wcat).fit()

# %%
model_quad.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             np.log(AT)   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                     186.8
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):           1.80e-35
# Time:                        11:08:06   Log-Likelihood:                -24.779
# No. Observations:                 109   AIC:                             55.56
# Df Residuals:                     106   BIC:                             63.63
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -7.8241      1.473     -5.312      0.000     -10.744      -4.904
# Waist          0.2289      0.032      7.107      0.000       0.165       0.293
# Waist_sq      -0.0010      0.000     -5.871      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        0.325   Durbin-Watson:                   1.464
# Prob(Omnibus):                  0.850   Jarque-Bera (JB):                0.271
# Skew:                           0.119   Prob(JB):                        0.873
# Kurtosis:                       2.949   Cond. No.                     4.49e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pred_quad=model_quad.predict(wcat)
pred4=np.exp(pred_quad)
pred4
# Out:
# 0       36.779400
# 1       31.026570
# 2       60.145769
# 3       68.488132
# 4       36.497176
# 5       29.174597
# 6       56.804132
# 7       66.309110
# 8       13.610862
# 9       32.565621
# 10      29.295590
# 11      37.491210
# 12      32.305552
# 13      50.075256
# 14      43.505263
# 15      22.548823
# 16      40.277322
# 17      35.107507
# 18      34.156014
# 19      40.127488
# 20      43.034658
# 21      56.804132
# 22      53.205658
# 23      90.409485
# 24      60.901036
# 25     102.467180
# 26      79.346903
# 27      55.349922
# 28      76.842525
# 29      62.808612
#           ...
# 79     155.642311
# 80     144.980610
# 81     156.625326
# 82     156.625326
# 83     157.645795
# 84     155.034904
# 85     146.290109
# 86     157.294508
# 87     155.034904
# 88     146.783920
# 89     155.642311
# 90     125.093851
# 91     149.832482
# 92     126.995763
# 93     113.052967
# 94     123.157825
# 95     148.717813
# 96     150.878818
# 97     130.687397
# 98      98.166004
# 99     142.179763
# 100    150.878818
# 101    155.754580
# 102    156.780640
# 103    137.554384
# 104    134.555999
# 105    108.012957
# 106    140.081911
# 107    154.205675
# 108    155.034904
# Length: 109, dtype: float64

# %%
rmse_quad=np.sqrt(np.mean((np.array(wcat['AT'])-np.array(pred4))**2))
rmse_quad
# Out:
# 32.24444782776221

# %%
plt.scatter(wcat.Waist,wcat.AT,c='b')
plt.plot(wcat.Waist,pred4,'r')

# %%
data={'MODEL':pd.Series(['rmse_lin','rmse_log','rmse_exp','rmse_quad']),
      'RMSE_VALUES':pd.Series(['rmse_lin','rmse_log','rmse_exp','rmse_quad']),
      'RSquare':pd.Series([model.rsquared,model2.rsquared,model3.rsquared,model_quad.rsquared])}
table=pd.DataFrame(data)
table
# Out:
#        MODEL RMSE_VALUES   RSquare
# 0   rmse_lin    rmse_lin  0.670037
# 1   rmse_log    rmse_log  0.675319
# 2   rmse_exp    rmse_exp  0.707114
# 3  rmse_quad   rmse_quad  0.778982
