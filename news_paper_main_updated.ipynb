# %% [markdown]
# <a href="https://colab.research.google.com/github/mounika8423/pythonbasics/blob/main/news_paper_main_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("NewspaperData.csv")
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 944.0+ bytes

# %%
data.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
data.isnull().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
plt.plot(data.daily,data.sunday,'bo')
plt.xlabel('daily')
plt.ylabel('sunday')
plt.title('scatterplot sunday vs daily')
# Out:
# Text(0.5, 1.0, 'scatterplot sunday vs daily')

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
sns.distplot(data['daily'])
# Out:
# <Axes: xlabel='daily', ylabel='Density'>

# %%
sns.regplot(x='daily',y='sunday',data=data)
# Out:
# <Axes: xlabel='daily', ylabel='sunday'>

# %%
data=data.drop('Newspaper',axis=1)

# %%
data.corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import statsmodels.formula.api as smf
model=smf.ols('sunday~daily',data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Sun, 25 Aug 2024   Prob (F-statistic):           6.02e-19
# Time:                        10:32:13   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
model.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept     0.386427
# daily        18.934840
# dtype: float64
#  Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9180596895873295, 0.9154990548869336)

# %%
newdata=pd.Series([200,250,300])

# %%
data_pred=pd.DataFrame(newdata,columns=['daily'])

# %%
model.predict(data_pred)
# Out:
# 0    281.778581
# 1    348.764319
# 2    415.750057
# dtype: float64

# %%
model.predict(data['daily'])
# Out:
# 0      538.939509
# 1      706.442705
# 2      490.275710
# 3      333.431284
# 4      734.307432
# 5      996.884826
# 6      280.213795
# 7      352.279731
# 8      290.090172
# 9      323.546868
# 10     616.379041
# 11     400.438457
# 12     262.668890
# 13    1573.783417
# 14     609.447357
# 15     566.965002
# 16     378.613164
# 17    1061.219269
# 18    1633.852208
# 19    1119.786239
# 20     313.594128
# 21     489.224034
# 22     704.489401
# 23     309.195844
# 24     466.219792
# 25     277.920203
# 26     192.337885
# 27     514.901007
# 28     380.708478
# 29     777.960698
# 30     538.047259
# 31     284.270451
# 32     444.722729
# 33    1137.725020
# dtype: float64
